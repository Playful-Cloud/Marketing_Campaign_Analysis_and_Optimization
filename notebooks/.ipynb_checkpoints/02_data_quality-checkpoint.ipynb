# %% [markdown]
# # DATA QUALITY

# %% [markdown]
# My Goal: Assess the health of the ingested data.
# Tasks:
#
# Inspect dimensions (df.shape, df.info(), df.describe())
#
# Missing values report (df.isna().sum())
#
# Check duplicates
#
# Validate column types (e.g., dates, integers, floats)
#
# Outlier detection (basic stats, boxplots)
#
# High-level summary → like a "data health report"

# %% [markdown]
# ## marketing_campaign_2024.csv

# %%
import pandas as pd
import numpy as np

# %%
#LOAD DATA
#LOAD 1ST CSV - 2024 FILE

df1 = pd.read_csv("../data/raw/marketing_campaign_2024.csv")

# %%
df1.head()
# Out:
#   campaign_id       campaign_name  start_date    end_date  channel  \
# 0   2024_0001  Campaign_2024_0001  2024-05-16  2024-08-16   Search
# 1   2024_0002  Campaign_2024_0002  2024-04-06  2024-10-13   Search
# 2   2024_0003  Campaign_2024_0003  2024-05-08  2024-11-27   Social
# 3   2024_0004  Campaign_2024_0004  2024-01-28  2024-08-03  Display
# 4   2024_0005  Campaign_2024_0005  2024-02-06  2024-08-23   Social
#
#           region  impressions  clicks  conversions  spend_usd  revenue_usd  \
# 0  South America        28252    5609        65466   39193.43     79017.74
# 1           Asia        89608   83584        26865   17291.53     49868.54
# 2         Europe        37853   62661        43662    6729.63     63021.28
# 3         Africa        10577   41421        75023   15077.58    133106.71
# 4           Asia        84039   56010        11283   16877.69    144736.99
#
#   target_audience product_category   device  year
# 0           Youth      Electronics  Desktop  2024
# 1          Adults             Home   Mobile  2024
# 2         Seniors      Electronics  Desktop  2024
# 3         Seniors         Clothing  Desktop  2024
# 4          Adults             Home   Mobile  2024

# %%
#INSPECT
print(df1.shape)
print(type(df1))
print(df1.keys())
df1.info()
df1.head()
# Out:
# (500, 15)
# <class 'pandas.core.frame.DataFrame'>
# Index(['campaign_id', 'campaign_name', 'start_date', 'end_date', 'channel',
#        'region', 'impressions', 'clicks', 'conversions', 'spend_usd',
#        'revenue_usd', 'target_audience', 'product_category', 'device', 'year'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   campaign_id       500 non-null    object
#  1   campaign_name     500 non-null    object
#  2   start_date        500 non-null    object
#  3   end_date          500 non-null    object
#  4   channel           500 non-null    object
#  5   region            500 non-null    object
#  6   impressions       500 non-null    int64
#  7   clicks            500 non-null    int64
#  8   conversions       500 non-null    int64
#  9   spend_usd         500 non-null    float64
#  10  revenue_usd       500 non-null    float64
#  11  target_audience   500 non-null    object
#  12  product_category  500 non-null    object
#  13  device            500 non-null    object
#  14  year              500 non-null    int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 58.7+ KB
#   campaign_id       campaign_name  start_date    end_date  channel  \
# 0   2024_0001  Campaign_2024_0001  2024-05-16  2024-08-16   Search
# 1   2024_0002  Campaign_2024_0002  2024-04-06  2024-10-13   Search
# 2   2024_0003  Campaign_2024_0003  2024-05-08  2024-11-27   Social
# 3   2024_0004  Campaign_2024_0004  2024-01-28  2024-08-03  Display
# 4   2024_0005  Campaign_2024_0005  2024-02-06  2024-08-23   Social
#
#           region  impressions  clicks  conversions  spend_usd  revenue_usd  \
# 0  South America        28252    5609        65466   39193.43     79017.74
# 1           Asia        89608   83584        26865   17291.53     49868.54
# 2         Europe        37853   62661        43662    6729.63     63021.28
# 3         Africa        10577   41421        75023   15077.58    133106.71
# 4           Asia        84039   56010        11283   16877.69    144736.99
#
#   target_audience product_category   device  year
# 0           Youth      Electronics  Desktop  2024
# 1          Adults             Home   Mobile  2024
# 2         Seniors      Electronics  Desktop  2024
# 3         Seniors         Clothing  Desktop  2024
# 4          Adults             Home   Mobile  2024

# %%
#INSPECT df1 2

#last 5 row of the table

df1.tail()
# Out:
#     campaign_id       campaign_name  start_date    end_date  channel  \
# 495   2024_0496  Campaign_2024_0496  2024-05-01  2024-08-28    Print
# 496   2024_0497  Campaign_2024_0497  2024-04-18  2024-11-25    Email
# 497   2024_0498  Campaign_2024_0498  2024-02-20  2024-10-01  Display
# 498   2024_0499  Campaign_2024_0499  2024-02-15  2024-09-25    Print
# 499   2024_0500  Campaign_2024_0500  2024-04-13  2024-11-05    Email
#
#             region  impressions  clicks  conversions  spend_usd  revenue_usd  \
# 495           Asia        87499   39992        23830   27953.15    148046.83
# 496  South America        73716   33091        63260   30243.81     62698.23
# 497         Europe        14446   50646        20254    2274.00    126139.27
# 498         Africa        18805   89455        18272   35779.91     11580.95
# 499  North America        44278    3427        19122   35432.96     41582.22
#
#     target_audience product_category   device  year
# 495         Seniors           Travel  Desktop  2024
# 496          Adults             Home   Mobile  2024
# 497           Youth         Clothing  Desktop  2024
# 498           Youth         Clothing   Mobile  2024
# 499           Youth         Services   Tablet  2024

# %%
#SUMMARY STATS

df1.describe()
# Out:
#         impressions        clicks   conversions     spend_usd    revenue_usd  \
# count    500.000000    500.000000    500.000000    500.000000     500.000000
# mean   49529.892000  44234.936000  44482.566000  25386.073380   75681.618100
# std    28345.677897  25362.277923  24514.539571  13811.344045   42423.908368
# min     1034.000000     86.000000    143.000000   1071.550000    1148.920000
# 25%    25028.750000  21953.750000  23687.750000  14075.640000   40132.227500
# 50%    48471.000000  43900.500000  44054.500000  25980.890000   74979.460000
# 75%    72818.250000  65160.750000  66064.500000  36842.002500  113579.197500
# max    99915.000000  89761.000000  84983.000000  49908.450000  149599.720000
#
#          year
# count   500.0
# mean   2024.0
# std       0.0
# min    2024.0
# 25%    2024.0
# 50%    2024.0
# 75%    2024.0
# max    2024.0

# %%
#COUNT OF NULL VALUES

df1.isnull().sum()
# Out:
# campaign_id         0
# campaign_name       0
# start_date          0
# end_date            0
# channel             0
# region              0
# impressions         0
# clicks              0
# conversions         0
# spend_usd           0
# revenue_usd         0
# target_audience     0
# product_category    0
# device              0
# year                0
# dtype: int64

# %%
#DUPLICATE ROWS

df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
#UNIQUE VALUES

df1.nunique()
# Out:
# campaign_id         500
# campaign_name       500
# start_date          167
# end_date            170
# channel               5
# region                5
# impressions         499
# clicks              498
# conversions         498
# spend_usd           499
# revenue_usd         500
# target_audience       3
# product_category      5
# device                3
# year                  1
# dtype: int64

# %%
#just need to onfirm the uniqueness of this column

df1['campaign_id'].is_unique
# Out:
# True

# %% [markdown]
# ## marketing_campaign_2025.csv

# %%
#LOAD DATA
#LOAD 2nd CSV - 2024 FILE

df2 = pd.read_csv("../data/raw/marketing_campaign_2025.csv")

# %%
#INSPECT


print(df2.shape)
print(type(df2))
print(df1.keys())
df2.info()
df2.head()
# Out:
# (500, 15)
# <class 'pandas.core.frame.DataFrame'>
# Index(['campaign_id', 'campaign_name', 'start_date', 'end_date', 'channel',
#        'region', 'impressions', 'clicks', 'conversions', 'spend_usd',
#        'revenue_usd', 'target_audience', 'product_category', 'device', 'year'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   campaign_id       500 non-null    object
#  1   campaign_name     500 non-null    object
#  2   start_date        500 non-null    object
#  3   end_date          500 non-null    object
#  4   channel           500 non-null    object
#  5   region            500 non-null    object
#  6   impressions       500 non-null    int64
#  7   clicks            500 non-null    int64
#  8   conversions       500 non-null    int64
#  9   spend_usd         500 non-null    float64
#  10  revenue_usd       500 non-null    float64
#  11  target_audience   500 non-null    object
#  12  product_category  500 non-null    object
#  13  device            500 non-null    object
#  14  year              500 non-null    int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 58.7+ KB
#   campaign_id       campaign_name  start_date    end_date  channel  \
# 0   2025_0001  Campaign_2025_0001  2025-03-04  2025-07-20  Display
# 1   2025_0002  Campaign_2025_0002  2025-04-05  2025-07-25    Print
# 2   2025_0003  Campaign_2025_0003  2025-03-18  2025-12-06    Print
# 3   2025_0004  Campaign_2025_0004  2025-03-09  2025-11-02   Search
# 4   2025_0005  Campaign_2025_0005  2025-05-21  2025-09-28    Email
#
#           region  impressions  clicks  conversions  spend_usd  revenue_usd  \
# 0  North America         7696    3587        15144   11046.09    117455.53
# 1           Asia        79664   30373        75743   16419.25     92144.07
# 2  North America        33324   89728        79251   33333.21     24070.68
# 3           Asia        32528   33793         4948   14340.82     13570.48
# 4         Africa        80785   35905        36563   37133.14    122995.42
#
#   target_audience product_category   device  year
# 0         Seniors         Services  Desktop  2025
# 1           Youth             Home   Tablet  2025
# 2           Youth         Clothing  Desktop  2025
# 3          Adults           Travel   Mobile  2025
# 4         Seniors         Services   Tablet  2025

# %%
#INSPECT df1 2

#last 5 row of the table

df2.tail()
# Out:
#     campaign_id       campaign_name  start_date    end_date  channel  \
# 495   2025_0496  Campaign_2025_0496  2025-05-20  2025-12-20    Email
# 496   2025_0497  Campaign_2025_0497  2025-06-23  2025-08-26  Display
# 497   2025_0498  Campaign_2025_0498  2025-05-02  2025-07-19  Display
# 498   2025_0499  Campaign_2025_0499  2025-06-25  2025-10-13  Display
# 499   2025_0500  Campaign_2025_0500  2025-02-20  2025-09-21  Display
#
#             region  impressions  clicks  conversions  spend_usd  revenue_usd  \
# 495  North America        83026    8493        76635   29145.05     34132.73
# 496  South America        12234   85523         4651   32650.42     67049.13
# 497  South America        41981   46904        71134   45470.59     74439.37
# 498         Europe        36670   69024        78323   23816.56     60359.37
# 499  North America        97262   80896        20752   43732.86    115423.95
#
#     target_audience product_category  device  year
# 495         Seniors           Travel  Mobile  2025
# 496         Seniors      Electronics  Mobile  2025
# 497          Adults         Services  Mobile  2025
# 498         Seniors         Clothing  Tablet  2025
# 499          Adults      Electronics  Tablet  2025

# %%
#SUMMARY STATS

df2.describe()
# Out:
#         impressions        clicks   conversions     spend_usd    revenue_usd  \
# count    500.000000    500.000000    500.000000    500.000000     500.000000
# mean   50620.932000  45490.010000  40454.040000  25331.606260   74960.419060
# std    28696.593254  26332.801902  24770.481236  14106.355565   44323.307634
# min     1073.000000    286.000000     30.000000   1066.110000    1098.660000
# 25%    24678.500000  24989.750000  18424.000000  13225.042500   36608.575000
# 50%    50492.000000  44961.000000  39757.500000  24196.835000   74207.955000
# 75%    74645.500000  68265.250000  62067.500000  37519.815000  113853.337500
# max    99902.000000  89865.000000  84813.000000  49838.540000  149713.740000
#
#          year
# count   500.0
# mean   2025.0
# std       0.0
# min    2025.0
# 25%    2025.0
# 50%    2025.0
# 75%    2025.0
# max    2025.0

# %%
#COUNT OF NULL VALUES

df2.isnull().sum()
# Out:
# campaign_id         0
# campaign_name       0
# start_date          0
# end_date            0
# channel             0
# region              0
# impressions         0
# clicks              0
# conversions         0
# spend_usd           0
# revenue_usd         0
# target_audience     0
# product_category    0
# device              0
# year                0
# dtype: int64

# %%
#DUPLICATE ROWS

df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
#UNIQUE VALUES

df2.nunique()
# Out:
# campaign_id         500
# campaign_name       500
# start_date          169
# end_date            173
# channel               5
# region                5
# impressions         500
# clicks              499
# conversions         499
# spend_usd           500
# revenue_usd         500
# target_audience       3
# product_category      5
# device                3
# year                  1
# dtype: int64

# %%
#just need to onfirm the uniqueness of this column

df2['campaign_id'].is_unique
# Out:
# True
